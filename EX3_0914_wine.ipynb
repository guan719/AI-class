# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wine.csv")

# %%
X = df.drop("Wine", axis=1)
y = df["Wine"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((142, 13), (36, 13), (142,), (36,))

# %% [markdown]
# Classification 4

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = model.predict(X_test)
print(classification_report(y_test, pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.86      1.00      0.92         6
#            2       0.83      0.90      0.86        21
#            3       0.83      0.56      0.67         9
#
#     accuracy                           0.83        36
#    macro avg       0.84      0.82      0.82        36
# weighted avg       0.83      0.83      0.82        36

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf = RandomForestClassifier()
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pred_rf = model_rf.predict(X_test)
print(classification_report(y_test, pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.86      1.00      0.92         6
#            2       1.00      0.90      0.95        21
#            3       0.90      1.00      0.95         9
#
#     accuracy                           0.94        36
#    macro avg       0.92      0.97      0.94        36
# weighted avg       0.95      0.94      0.94        36

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

model_lr = make_pipeline(
    StandardScaler(),
    LogisticRegression(max_iter=1000)
)

model_lr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(max_iter=1000))])

# %%
pred_lr = model_lr.predict(X_test)
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.86      1.00      0.92         6
#            2       0.95      0.90      0.93        21
#            3       0.89      0.89      0.89         9
#
#     accuracy                           0.92        36
#    macro avg       0.90      0.93      0.91        36
# weighted avg       0.92      0.92      0.92        36

# %%
from sklearn.neighbors import KNeighborsClassifier
model_kn = KNeighborsClassifier()
model_kn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
pred_kn = model_kn.predict(X_test)
print(classification_report(y_test, pred_kn))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.50      0.83      0.62         6
#            2       0.85      0.52      0.65        21
#            3       0.31      0.44      0.36         9
#
#     accuracy                           0.56        36
#    macro avg       0.55      0.60      0.55        36
# weighted avg       0.65      0.56      0.57        36

# %% [markdown]
# Regression

# %%
X_reg = df.drop(["Alcohol", "Wine"], axis=1)
y_reg = df["Alcohol"]

X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
    X_reg,
    y_reg,
    test_size=0.2,
    random_state=0
)

X_train_reg.shape, X_test_reg.shape, y_train_reg.shape, y_test_reg.shape
# Out:
# ((142, 12), (36, 12), (142,), (36,))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

model_lr_reg = LinearRegression()

model_lr_reg.fit(X_train_reg, y_train_reg)

pred_lr_reg = model_lr_reg.predict(X_test_reg)

print("MSE:", mean_squared_error(y_test_reg, pred_lr_reg))
print("R2:", r2_score(y_test_reg, pred_lr_reg))
# Out:
# MSE: 0.39482077365100593
# R2: 0.4225356196388831

# %%
from sklearn.tree import DecisionTreeRegressor

model_dt_reg = DecisionTreeRegressor(random_state=0)

model_dt_reg.fit(X_train_reg, y_train_reg)

pred_dt_reg = model_dt_reg.predict(X_test_reg)

print("MSE:", mean_squared_error(y_test_reg, pred_dt_reg))
print("R2:", r2_score(y_test_reg, pred_dt_reg))
# Out:
# MSE: 0.6756833333333335
# R2: 0.011746383566529017

# %%
from sklearn.ensemble import RandomForestRegressor

model_rf_reg = RandomForestRegressor(random_state=0)

model_rf_reg.fit(X_train_reg, y_train_reg)

pred_rf_reg = model_rf_reg.predict(X_test_reg)

print("MSE:", mean_squared_error(y_test_reg, pred_rf_reg))
print("R2:", r2_score(y_test_reg, pred_rf_reg))
# Out:
# MSE: 0.5381560083333309
# R2: 0.21289368080587767

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

model_kn_reg = make_pipeline(
    StandardScaler(),
    KNeighborsRegressor(n_neighbors=5)
)

model_kn_reg.fit(X_train_reg, y_train_reg)

pred_kn_reg = model_kn_reg.predict(X_test_reg)

print("KNN Regression")
print("MSE:", mean_squared_error(y_test_reg, pred_kn_reg))
print("R2:", r2_score(y_test_reg, pred_kn_reg))
# Out:
# KNN Regression
# MSE: 0.320043555555556
# R2: 0.5319046873130837

# %%
print("Linear Regression")
print("MSE:", mean_squared_error(y_test_reg, pred_lr_reg))
print("R2 :", r2_score(y_test_reg, pred_lr_reg))

print("\nDecision Tree Regression")
print("MSE:", mean_squared_error(y_test_reg, pred_dt_reg))
print("R2 :", r2_score(y_test_reg, pred_dt_reg))

print("\nRandom Forest Regression")
print("MSE:", mean_squared_error(y_test_reg, pred_rf_reg))
print("R2 :", r2_score(y_test_reg, pred_rf_reg))

print("\nKNN Regression")
print("MSE:", mean_squared_error(y_test_reg, pred_kn_reg))
print("R2 :", r2_score(y_test_reg, pred_kn_reg))
# Out:
# Linear Regression
# MSE: 0.39482077365100593
# R2 : 0.4225356196388831
#
# Decision Tree Regression
# MSE: 0.6756833333333335
# R2 : 0.011746383566529017
#
# Random Forest Regression
# MSE: 0.5381560083333309
# R2 : 0.21289368080587767
#
# KNN Regression
# MSE: 0.320043555555556
# R2 : 0.5319046873130837
